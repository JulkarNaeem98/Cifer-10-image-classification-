# %% [markdown]
# ## <font color="blue">Let's enjoy Cifer-10 dataset and classification by using CNN deep learning tech.<font>
#
# ### What is Cifer-10?
#     CIFAR-10 is a dataset that consists of 60000 32x32 colour images in 10 classes like
#     "airplane","automobile","bird","cat","deer","dog","frog" .etc.
#
# ### What is CNN?
#     CNN stands for Convolutional Neural Network. CNN is a most commonly applied to analyze
#     visual imagery like this.

# %% [markdown]
# ## 1. load dataset.

# %%
from keras.datasets import cifar10

# %% [markdown]
# ## 2. import libraries

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras as kr
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 3. Split the dataset into x_train,y_train,x_test,y_test.

# %%
#load cifer10 dataset and split it.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# ## 4. Change train data and test data into float32 and divide by 255.

# %%
#change train data and test data into float32 and divide by 255
#That normalizes data from 1 to 0. 
x_train = x_train.astype('float32')/255
y_train = y_train.astype('float32')
x_test = x_test.astype('float32')/255

# %% [markdown]
# ## 5. Convert y_train and y_test into 10 categories

# %%
#convert y_train and y_test into 10 categories
y_train = kr.utils.to_categorical(y_train, 10)
y_test  = kr.utils.to_categorical(y_test,10)

# %% [markdown]
# ## 6. Let's show images of Cifer-10 images.

# %%
plt.figure(figsize=(8,8))
for i in range(10):
    plt.subplot(5, 5, i+1)
    plt.title(i)
    plt.imshow(x_train[i].reshape(32,32,3))

# %% [markdown]
# ## 7. Let's build 1st CNN model with Adam optimizer.

# %%
#build 1st model
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',padding='same', input_shape=x_train.shape[1:]))
model.add(Conv2D(32,(3,3),padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 4,210,090
# Trainable params: 4,210,090
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 8. Let's fit 1st CNN model with Adam optimizer.

# %%
#model fitting
result1=model.fit(x_train, y_train,batch_size=128, epochs=20)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 9s 6ms/step - loss: 1.7830 - accuracy: 0.3692
# Epoch 2/20
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1132 - accuracy: 0.6067
# Epoch 3/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.9057 - accuracy: 0.6821
# Epoch 4/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.7510 - accuracy: 0.7386
# Epoch 5/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.6108 - accuracy: 0.7904
# Epoch 6/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4596 - accuracy: 0.8438
# Epoch 7/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.3281 - accuracy: 0.8928
# Epoch 8/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.2113 - accuracy: 0.9363
# Epoch 9/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1378 - accuracy: 0.9597
# Epoch 10/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0836 - accuracy: 0.9778
# Epoch 11/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0517 - accuracy: 0.9868
# Epoch 12/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0414 - accuracy: 0.9900
# Epoch 13/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0463 - accuracy: 0.9868
# Epoch 14/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0370 - accuracy: 0.9899
# Epoch 15/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0358 - accuracy: 0.9899
# Epoch 16/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0377 - accuracy: 0.9879
# Epoch 17/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0354 - accuracy: 0.9894
# Epoch 18/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0324 - accuracy: 0.9901
# Epoch 19/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.9959
# Epoch 20/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0270 - accuracy: 0.9913

# %% [markdown]
# ## 9. Let's build 2nd CNN model with RMSprop optimizer.

# %%
#Build 2nd model.
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',padding='same', input_shape=x_train.shape[1:]))
model.add(Conv2D(32,(3,3),padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1048704
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,060,138
# Trainable params: 1,060,138
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 10. Let's fit 2nd CNN model with RMSprop optimizer.

# %%
#model fitting
result2=model.fit(x_train, y_train,batch_size=128, epochs=20)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 3s 5ms/step - loss: 1.7507 - accuracy: 0.3801
# Epoch 2/20
# 391/391 [==============================] - 2s 5ms/step - loss: 1.1369 - accuracy: 0.6033
# Epoch 3/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.9458 - accuracy: 0.6759
# Epoch 4/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.8070 - accuracy: 0.7211
# Epoch 5/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.6990 - accuracy: 0.7565
# Epoch 6/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.5934 - accuracy: 0.7906
# Epoch 7/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4897 - accuracy: 0.8310
# Epoch 8/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4021 - accuracy: 0.8620
# Epoch 9/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.3193 - accuracy: 0.8927
# Epoch 10/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.2377 - accuracy: 0.9213
# Epoch 11/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1799 - accuracy: 0.9420
# Epoch 12/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1343 - accuracy: 0.9564
# Epoch 13/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1018 - accuracy: 0.9684
# Epoch 14/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0826 - accuracy: 0.9743
# Epoch 15/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0645 - accuracy: 0.9795
# Epoch 16/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0514 - accuracy: 0.9845
# Epoch 17/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0469 - accuracy: 0.9854
# Epoch 18/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9886
# Epoch 19/20
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0355 - accuracy: 0.9887
# Epoch 20/20
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0303 - accuracy: 0.9904

# %% [markdown]
# ## 11. Evaluate the two models by using two metrics, loss and accuracy.

# %%
#Evaluate the two models by using two metrics, loss and accuracy.
metrics = ['loss', 'accuracy']
#show the evaluation result by using matoplot.
plt.figure(figsize=(10, 5))
#Use "For Loop".
for i in range(len(metrics)):
    metric = metrics[i]
    #set subplots to show the result
    plt.subplot(1, 2, i+1)
    #Titles of subplots are "loss" and "accuracy"
    plt.title(metric) 
    plt_result1 = result1.history[metric] 
    plt_result2 = result2.history[metric]

    #plot them all
    plt.plot(plt_result1, label='1st model') 
    plt.plot(plt_result2, label='2nd model') 
    plt.legend() 
plt.show()

# %% [markdown]
# The 1st model is better.

# %% [markdown]
# ## 12. How to predict a single photo data?

# %%
plt.imshow(x_test[[98]].reshape(32,32,3))

# %%
#Let's predict.
prediction=model.predict(x_test[[98]]) 
prediction
# Out:
# array([[9.9680281e-01, 5.4441732e-26, 3.1971585e-03, 1.1025383e-10,
#         1.2927139e-20, 7.2037560e-25, 3.3004068e-12, 7.7922159e-23,
#         1.0148091e-29, 1.6862332e-38]], dtype=float32)

# %%
names=["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
#Preparation for this predction. 
list1=[]
[list1.append(i) for i in range(26)]
list2=[]
[list2.append(i) for i in names]
dic = dict(zip(list1, list2))
#Let's check the result.
print("The answer is",dic[np.argmax(prediction)],"!")
# Out:
# The answer is airplane !

# %% [markdown]
# <B>"Correct!"<B>

# %% [markdown]
# ## 13. Let's predict whole test data!

# %%
#Let's predict whole test data! 
predictions = model.predict(x_test)
results = np.argmax(predictions,axis=1)
results = pd.Series(results, name="Label")
results.tail()
# Out:
# 9995    8
# 9996    3
# 9997    5
# 9998    1
# 9999    7
# Name: Label, dtype: int64

# %% [markdown]
# Thanks for reading my notebook :-)
